# %%
# !python extreme_run_gpu.py
# Out:
# GPU available: True
#
# === Loading data ===
# Saved final_processed_X.csv and final_labels.csv
# Classes: ['T3 toxic', 'compensated hypothyroid', 'decreased binding protein', 'discordant', 'goitre', 'hyperthyroid', 'increased binding protein', 'negative', 'overreplacement', 'primary hypothyroid', 'replacement therapy', 'secondary hypothyroid', 'secondary toxic', 'sick', 'underreplacement']
# Adaptive CV folds: 5
#
# === Optuna search (XGBoost) ===
# [I 2026-03-12 08:09:03,995] A new study created in memory with name: no-name-c2aaa580-e19a-41a4-894b-a97f8d69ea3c
# [I 2026-03-12 08:09:16,154] Trial 0 finished with value: 0.9870979144574054 and parameters: {'learning_rate': 0.025599706536604937, 'max_depth': 18, 'subsample': 0.892797576724562, 'colsample_bytree': 0.7993292420985183, 'n_estimators': 324, 'min_child_weight': 1.7799726016810133, 'gamma': 0.05808361216819946, 'reg_lambda': 3.531616510212273}. Best is trial 0 with value: 0.9870979144574054.
# ...

# %%
# !python paper_dashboard.py
# Out:
# [conv] saved
# [ablation] saved
# [runtime] saved
# [sens] saved
# [robust] saved
# [corr] saved
# [feat] Computing Gain and Permutation Importance for EvoX-Boost…
# [feat] Gain importance saved
# [feat] Running Permutation Importance (this may take ~20–90 sec)…
# [feat] Permutation importance saved
# [metrics] saved final_metrics_summary.csv
# [roc] saved XGB ROC
# [acc] saved
# [time] saved runtime
# [size] saved model sizes
#
# All figures saved to ./output/figs/
